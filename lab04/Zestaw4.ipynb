# %% [markdown]
# # Zestaw 4

# %% [markdown]
# ### Kamil Burkiewicz

# %% [markdown]
# Zadanie dotyczy wykorzystania odległości edycyjnej.
#
# 1. Zaimplementuj algorytm obliczania odległości edycyjnej w taki sposób, aby możliwe było określenie przynajmniej jednej sekwencji edycji (dodanie, usunięcie, zmiana znaku), która pozwala w minimalnej liczbie kroków, przekształcić jeden łańcuch w drugi.
# 2. Na podstawie poprzedniego punktu zaimplementuj prostą wizualizację działania algorytmu, poprzez wskazanie kolejnych wersji pierwszego łańcucha, w których dokonywana jest określona zmiana. "Wizualizacja" może działać w trybie tekstowym. Np. zmiana łańcuch "los" w "kloc" może być zrealizowana następująco:
# *k*los (dodanie litery k)
# klo*c* (zamiana s->c)
# 3. Przedstaw wynik działania algorytmu z p. 2 dla następujących par łańcuchów:
#   * los - kloc
#   * Łódź - Lodz
#   * kwintesencja - quintessence
#   * ATGAATCTTACCGCCTCG - ATGAGGCTCTGGCCCCTG
#
# 4. Zaimplementuj algorytm obliczania najdłuższego wspólnego podciągu dla pary ciągów elementów.
# 5. Korzystając z gotowego tokenizera (np spaCy - https://spacy.io/api/tokenizer) dokonaj podziału załączonego tekstu na tokeny.
# 6. Stwórz 2 wersje załączonego tekstu, w których usunięto 3% losowych tokenów.
# 7. Oblicz długość najdłuższego podciągu wspólnych tokenów dla tych tekstów.
# 8. Korzystając z algorytmu z punktu 4 skonstruuj narzędzie, o działaniu podobnym do narzędzia diff, tzn. wskazującego w dwóch plikach linie, które się różnią. Na wyjściu narzędzia powinny znaleźć się elementy, które nie należą do najdłuższego wspólnego podciągu. Należy wskazać skąd dana linia pochodzi (< > - pierwszy/drugi plik) oraz numer linii w danym pliku.
# 9. Przedstaw wynik działania narzędzia na tekstach z punktu 6. Zwróć uwagę na dodanie znaków przejścia do nowej linii, które są usuwane w trakcie tokenizacji.

# %% [markdown]
# #### Imports

# %%
import numpy as np
from bisect import bisect
from unidecode import unidecode
import numpy as np
from enum import Enum
from termcolor import colored
from spacy.tokenizer import Tokenizer
from spacy.vocab import Vocab
from spacy.lang.pl import Polish

# %% [markdown]
# ### Code

# %% [markdown]
# #### Z1

# %%
def normal_delta(a,b):
    if a == b:
        return 0
    return 1

# %%
def edit_distance(x, y, delta):
    edit_table = np.empty((len(x) + 1, len(y) + 1))
    
    for i in range(len(x) + 1):
        edit_table[i, 0] = i
    for j in range(len(y) + 1):
        edit_table[0, j] = j
    for i in range(len(x)):
        k = i + 1
        for j in range(len(y)):
            l = j + 1
            edit_table[k, l] = min(edit_table[k-1, l] + 1,
                                  edit_table[k, l-1] + 1,
                                  edit_table[k-1, l-1] + delta(x[i], y[j]))

    return edit_table

# %% [markdown]
# #### Z2

# %%
class Operation(Enum):
    EQUAL = 0
    DELETE = 1
    INSERT = 2
    SUBSTITUTE = 3

# %%
def seq_of_editions(x, y, edit_table=None):
    if (edit_table is None):
        edit_table = edit_distance(x, y, normal_delta)
    
    i, j = len(x), len(y)
    seq = []
    
    while (i >= 0 and j >= 0):
        if (i == 0 and j == 0):
            break
        if (i > 0 and j > 0):
            # choose any minimal value from left, upper and upper-left cell
            if (edit_table[i - 1][j - 1] <= edit_table[i - 1][j] and
                            edit_table[i - 1][j - 1] <= edit_table[i][j - 1]):
                if (edit_table[i - 1][j - 1] == edit_table[i][j]):
                    i -= 1
                    j -= 1
                    seq += [(Operation.EQUAL, (i, j), (x[i], y[j]))]
                else:
                    i -= 1
                    j -= 1
                    seq += [(Operation.SUBSTITUTE, (i, j), (x[i], y[j]))]
            elif (edit_table[i - 1][j] <= edit_table[i][j - 1] and 
                     edit_table[i - 1][j] <= edit_table[i - 1][j - 1]):
                i -= 1
                seq += [(Operation.DELETE, (i, j), x[i])]
            else:
                j -= 1
                seq += [(Operation.INSERT, (i, j), y[j])]
        elif (i > 0):
            i -= 1
            seq += [(Operation.DELETE, (i, j), x[i])]
        else:
            j -= 1
            seq += [(Operation.INSERT, (i, j), y[j])]
            
    return list(reversed(seq))

# %%
def visualize(x, y, editions_sequence=None, verbose=False):
    if (editions_sequence is None):
        editions_sequence = seq_of_editions(x, y)
    
    DELETION_COLOR = "red"
    INSERTION_COLOR = "green"
    SUBSTITITUION_COLOR = "blue"
    WORD_COLOR = "magenta"
    
    if (verbose):
        print(colored(DELETION_COLOR + "\t- deletion", DELETION_COLOR))
        print(colored(INSERTION_COLOR + "\t- insertion", INSERTION_COLOR))
        print(colored(SUBSTITITUION_COLOR + "\t- substitution", SUBSTITITUION_COLOR))
        print(colored("word at the beginning and at the end", WORD_COLOR, attrs=["bold"]), end="\n\n")
        
    word = x
    idx = 0
    
    print(colored(word, color=WORD_COLOR, attrs=["bold"]))
    for operation in editions_sequence:
        letter = operation[2]
        if (operation[0] is Operation.DELETE):
            print(f"{word[:idx]}{colored(letter, DELETION_COLOR, attrs=['reverse'])}{word[idx + 1:]}")
            word = word[:idx] + word[idx + 1:]
            idx -= 1  # Let idx be at the same position after deletion
        elif (operation[0] is Operation.INSERT):
            print(f"{word[:idx]}{colored(letter, INSERTION_COLOR, attrs=['reverse'])}{word[idx:]}")
            word = word[:idx] + letter + word[idx:]
        elif (operation[0] is Operation.SUBSTITUTE):
            # In case of substitution the second element of opertaion is tuple; here only one is needed
            letter = letter[1]
            print(f"{word[:idx]}{colored(letter, SUBSTITITUION_COLOR, attrs=['reverse'])}{word[idx + 1:]}")
            word = word[:idx] + letter + word[idx + 1:]
        idx += 1
    print(colored(word, color=WORD_COLOR, attrs=["bold"]), end="\n\n")

# %% [markdown]
# #### Z4

# %%
def delta_lcs(x,y):
    if x == y:
        return 0
    else:
        return 2

# %%
def lcs(x, y):
    xlen = len(x)
    ylen = len(y)
    return int((xlen + ylen - edit_distance(x, y, delta_lcs)[xlen][ylen]) / 2)

# %%
def input_from_file(filename, remove_blank=False):
    """ Read text from file.
    """
    
    with open(filename, "r") as f:
        text = f.read()
    return text

# %%
_TOKENIZER_PL = Tokenizer(Polish(Vocab()).vocab)


def tokenize(text, remove_blank=False, punctuation_to_remove=None):
    """  Tokenize given text.
    All sequences of blank characters can be converted to single spaces
    and all punctuation 
    
    
    """

    if (remove_blank):
        text = " ".join(text.split())
    if (punctuation_to_remove):
        for punct in punctuation_to_remove:
            if (len(punct) == 1):
                text = text.replace(punct, '')
    docer = _TOKENIZER_PL(text)
    return list(map(str, docer))

# %%
def remove_tokens_randomly(tokens, p=0.5):
    """ Remove random tokens.
    
    Args:
        tokens (list): List of tokens.
        p: Probability of removing a word.
        
    Returns:
        list: List with tokens removed.
    """
    
    new_tokens = []
    for token in tokens:
        if (np.random.uniform() >= p):
            new_tokens += [token]
    
    return new_tokens

# %% [markdown]
# #### Z8

# %%
def diff(filename1, filename2):
    with open(filename1, "r") as f:
        text1 = f.read()
    with open(filename2, "r") as f:
        text2 = f.read()
    
    tokens1 = [t + '\n' for t in text1.split("\n")]
    tokens2 = [t + '\n' for t in text2.split("\n")]
    
    show_all=False
    if (show_all):
        for i in range(min(len(tokens1), len(tokens2))):
            print(repr(tokens1[i]), repr(tokens2[i]))
            
    edit_table = edit_distance(tokens1, tokens2, delta_lcs)
    changes = seq_of_editions(tokens1, tokens2, edit_table)
    last_change_num = sum(map(lambda op: 1 if (op[0] is not Operation.EQUAL) else 0, changes))
    change_num = 0
    for op in changes:
        #print(op)

        if (op[0] is not Operation.EQUAL):
            line1 = op[1][0]
            line2 = op[1][1]
            if (op[0] is Operation.DELETE):
                print(colored(f"{line1}d{line2}", color="red", attrs=["reverse"]))
                print("<", repr(op[2]))
            if (op[0] is Operation.INSERT):
                print(colored(f"{line1}a{line2}", color="green", attrs=["reverse"]))
                print("<", repr(op[2]))
            if (op[0] is Operation.SUBSTITUTE):
                print(colored(f"{line1}c{line2}", color="blue", attrs=["reverse"]))
                print("<", repr(op[2]))
                print(">", repr(tokens2[line2]))
            change_num += 1
            if (change_num < last_change_num):
                print("-" * 3)

# %% [markdown]
# ### Tests

# %%
x, y = "los", "kloc"
visualize(x, y, verbose=True)
x, y = "Łódź", "Lodz"
visualize(x, y)
x, y = "kwintesencja", "quintessence"
visualize(x, y)
x, y = "ATGAATCTTACCGCCTCG", "ATGAGGCTCTGGCCCCTG"
visualize(x ,y)
# Out:
# red	- deletion
# green	- insertion
# blue	- substitution
# word at the beginning and at the end
#
# los
# klos
# kloc
# kloc
#
# Łódź
# Lódź
# Lodź
# Lodz
# Lodz
#
# kwintesencja
# qwintesencja
# quintesencja
# quintessencja
# quintessencja
# quintessence
# quintessence
#
# ATGAATCTTACCGCCTCG
# ATGAGTCTTACCGCCTCG
# ATGAGGCTTACCGCCTCG
# ATGAGGCTCTACCGCCTCG
# ATGAGGCTCTGCCGCCTCG
# ATGAGGCTCTGGCGCCTCG
# ATGAGGCTCTGGCCCCTCG
# ATGAGGCTCTGGCCCCTCG
# ATGAGGCTCTGGCCCCTG

# %%
romeo_and_julia = input_from_file("romeo-i-julia-700.txt")
tokens = tokenize(romeo_and_julia, remove_blank=True, punctuation_to_remove=['.', ','])
random_tokens1 = remove_tokens_randomly(tokens, p=0.03)
random_tokens2 = remove_tokens_randomly(tokens, p=0.03)

# %%
print(f"Length of tokens list from original text: {len(tokens)}", end="\n\n")
print(f"Length of longest common subseuquence of tokens: {lcs(random_tokens1, random_tokens2)}")
print(f"\t\t\tVS\nlength of tokens lists of both texts: {len(random_tokens1)} {len(random_tokens2)}")
# Out:
# Length of tokens list from original text: 1888
#
# Length of longest common subseuquence of tokens: 1763
# 			VS
# length of tokens lists of both texts: 1826 1825

# %%
# Make valid test files with appropriate new lines 

# Do not remove blank sequences, new lines or punctuation
new_tokens = tokenize(romeo_and_julia)
random_tokens1_2 = remove_tokens_randomly(new_tokens, p=0.03)
random_tokens2_2 = remove_tokens_randomly(new_tokens, p=0.03)

with open("r&j1.txt", "w") as f:
    f.write(" ".join(random_tokens1_2))
with open("r&j2.txt", "w") as f:
    f.write(" ".join(random_tokens2_2))

# %%
diff("r&j1.txt", "r&j2.txt")
# Out:
# 0c0
# < ('Shakespeare \n', 'William Shakespeare \n')
# > 'William Shakespeare \n'
# ---
# 3c3
# < (' tłum. Józef Paszkowski \n', ' tłum. Józef \n')
# > ' tłum. Józef \n'
# ---
# 10a10
# < '  * ESKALUS — książę w Weronie \n'
# ---
# 10c11
# < ('  * ESKALUS — książę panujący w Weronie \n', '  * PARYS młody Weroneńczyk szlachetnego rodu, krewny księcia \n')
# > '  * PARYS młody Weroneńczyk szlachetnego rodu, krewny księcia \n'
# ---
# 11c12
# < ('  * PARYS — młody Weroneńczyk rodu, krewny księcia \n', '  * MONTEKI, KAPULET — naczelnicy domów nieprzyjaznych sobie \n')
# > '  * MONTEKI, KAPULET — naczelnicy domów nieprzyjaznych sobie \n'
# ---
# 12c13
# < ('  * MONTEKI, KAPULET — naczelnicy dwóch domów nieprzyjaznych sobie * STARZEC — stryjeczny brat Kapuleta \n', '  * STARZEC — stryjeczny brat Kapuleta \n')
# > '  * STARZEC — stryjeczny brat Kapuleta \n'
# ---
# 14c15
# < ('  * MERKUCJO — księcia \n', '  * MERKUCJO — krewny księcia \n')
# > '  * MERKUCJO — krewny księcia \n'
# ---
# 15c16
# < ('  * BENWOLIO — synowiec Montekiego \n', '  * BENWOLIO — Montekiego \n')
# > '  * BENWOLIO — Montekiego \n'
# ---
# 21d22
# < '  * ABRAHAM — służący Montekiego \n'
# ---
# 22c22
# < ('  * APTEKARZ \n', '  * ABRAHAM — służący Montekiego * APTEKARZ \n')
# > '  * ABRAHAM — służący Montekiego * APTEKARZ \n'
# ---
# 27c27
# < ('  * PANI MONTEKI — małżonka Montekiego \n', '  * MONTEKI — małżonka Montekiego \n')
# > '  * MONTEKI — małżonka Montekiego \n'
# ---
# 31c31
# < ('  * Obywatele weroneńscy, osoby płci obojej, liczący się do przyjaciół obu domów, maski, straż wojskowa i inne osoby. \n', '  * Obywatele weroneńscy, różne osoby płci obojej, liczący się do przyjaciół obu domów, maski, straż wojskowa i inne osoby. \n')
# > '  * Obywatele weroneńscy, różne osoby płci obojej, liczący się do przyjaciół obu domów, maski, straż wojskowa i inne osoby. \n'
# ---
# 36c36
# < (' Rzecz odbywa się przez większą część sztuki w Weronie, przez część piątego aktu w Mantui. \n', ' Rzecz odbywa się przez większą część sztuki w Weronie, przez część piątego aktu Mantui. \n')
# > ' Rzecz odbywa się przez większą część sztuki w Weronie, przez część piątego aktu Mantui. \n'
# ---
# 40c40
# < (' PROLOG \n', ' PROLOG Przełożył Jan Kasprowicz \n')
# > ' PROLOG Przełożył Jan Kasprowicz \n'
# ---
# 42d42
# < ' Przełożył Jan Kasprowicz \n'
# ---
# 43d42
# < '\n'
# ---
# 44c42
# < (' rody, zacne jednako i sławne — \n', ' Dwa rody, zacne jednako i sławne — \n')
# > ' Dwa rody, zacne jednako i sławne — \n'
# ---
# 49a47
# < ' Z łon tych dwu wrogów wzięło bowiem życie, \n'
# ---
# 49c48
# < (' Z łon tych dwu wrogów wzięło bowiem życie, Pod najstraszliwszą z gwiazd, kochanków dwoje; \n', ' najstraszliwszą z gwiazd, kochanków dwoje; \n')
# > ' najstraszliwszą z gwiazd, kochanków dwoje; \n'
# ---
# 53c52
# < (' Tej ich przebieg zbyt bolesny \n', ' Tej ich miłości przebieg zbyt bolesny \n')
# > ' Tej ich miłości przebieg zbyt bolesny \n'
# ---
# 55c54
# < (' Aż ją zakończy zgon przedwczesny, \n', ' Aż ją zakończy dzieci zgon przedwczesny, \n')
# > ' Aż ją zakończy dzieci zgon przedwczesny, \n'
# ---
# 58c57
# < (' otoczcie cierpliwymi względy, \n', ' Które otoczcie cierpliwymi względy, \n')
# > ' Które otoczcie cierpliwymi względy, \n'
# ---
# 70c69
# < (' / Plac publiczny. Wchodzą Samson i Grzegorz w tarcze i miecze. / \n', ' / Plac publiczny. Wchodzą Samson i Grzegorz uzbrojeni w tarcze i miecze. \n')
# > ' / Plac publiczny. Wchodzą Samson i Grzegorz uzbrojeni w tarcze i miecze. \n'
# ---
# 75c74
# < (' Dalipan, Grzegorzu, nie będziem darli pierza. \n', ' Grzegorzu, nie będziem darli pierza. \n')
# > ' Grzegorzu, nie będziem darli pierza. \n'
# ---
# 90c89
# < (' zechce zadrzeć z nami, będzie musiał zadrżeć. \n', ' Kto zadrzeć z nami, będzie musiał zadrżeć. \n')
# > ' Kto zadrzeć z nami, będzie musiał zadrżeć. \n'
# ---
# 95c94
# < (' Mam zwyczaj drapać zaraz, jak mię kto rozrucha. \n', ' Mam zwyczaj drapać zaraz, jak mię rozrucha. \n')
# > ' Mam zwyczaj drapać zaraz, jak mię rozrucha. \n'
# ---
# 115c114
# < (' Te psy z domu Montekich rozruchać mię mogą tylko do stania na miejscu. Będę jak mur dla każdego mężczyzny i każdej kobiety z tego domu. \n', ' Te psy z domu Montekich rozruchać mię mogą tylko do stania na miejscu. Będę jak mur dla każdego mężczyzny każdej kobiety z tego domu. \n')
# > ' Te psy z domu Montekich rozruchać mię mogą tylko do stania na miejscu. Będę jak mur dla każdego mężczyzny każdej kobiety z tego domu. \n'
# ---
# 120c119
# < (' To właśnie pokazuje słabą mur dla nikogo i tylko słabi go trzymają. \n', ' To właśnie pokazuje twoją słabą stronę; mur dla nikogo niestraszny i tylko słabi go się trzymają. \n')
# > ' To właśnie pokazuje twoją słabą stronę; mur dla nikogo niestraszny i tylko słabi go się trzymają. \n'
# ---
# 138c137
# < (' GRZEGORZ \n', ' \n')
# > ' \n'
# ---
# 140c139
# < (' Rzeź kobiet chcesz przedsiębrać? \n', ' Rzeź kobiet chcesz przedsiębrać? SAMSON Nie inaczej: wtłoczę miecz w każdą po kolei. Wiadomo, że się do lwów liczę. \n')
# > ' Rzeź kobiet chcesz przedsiębrać? SAMSON Nie inaczej: wtłoczę miecz w każdą po kolei. Wiadomo, że się do lwów liczę. \n'
# ---
# 143d142
# < ' SAMSON \n'
# ---
# 144d142
# < '\n'
# ---
# 145d142
# < ' Nie inaczej: wtłoczę miecz w każdą po kolei. Wiadomo, że się do lwów liczę. \n'
# ---
# 146d142
# < '\n'
# ---
# 147d142
# < '\n'
# ---
# 150c144
# < (' Tym lepiej, że się liczysz do zwierząt; bo gdybyś się liczył do ryb, to byłbyś pewnie sztokfiszem. Weź no się za bo oto nadchodzi dwóch domowników Montekiego. \n', ' Tym lepiej, że się liczysz do zwierząt; bo gdybyś się liczył do ryb, to byłbyś pewnie sztokfiszem. Weź no się za instrument, bo oto nadchodzi dwóch domowników Montekiego. \n')
# > ' Tym lepiej, że się liczysz do zwierząt; bo gdybyś się liczył do ryb, to byłbyś pewnie sztokfiszem. Weź no się za instrument, bo oto nadchodzi dwóch domowników Montekiego. \n'
# ---
# 162c156
# < (' drapania? \n', ' Gwoli \n')
# > ' Gwoli \n'
# ---
# 172c166
# < (' Ja bym bać z twojej przyczyny! \n', ' Ja bym się miał bać z twojej przyczyny! \n')
# > ' Ja bym się miał bać z twojej przyczyny! \n'
# ---
# 177c171
# < (' Miejmy prawo za sobą, niech zaczną. \n', ' Miejmy prawo za sobą, niech oni zaczną. \n')
# > ' Miejmy prawo za sobą, niech oni zaczną. \n'
# ---
# 182c176
# < (' Marsa im nastawię przechodząc; niech go sobie, jak tłumaczą. \n', ' Marsa im nastawię przechodząc; niech go sobie, jak chcą, tłumaczą. \n')
# > ' Marsa im nastawię przechodząc; niech go sobie, jak chcą, tłumaczą. \n'
# ---
# 212c206
# < (' GRZEGORZ \n', ' GRZEGORZ Nie. \n')
# > ' GRZEGORZ Nie. \n'
# ---
# 214d208
# < ' Nie. \n'
# ---
# 216d209
# < '\n'
# ---
# 231c223
# < (' nie. \n', ' Zaczepki? nie. \n')
# > ' Zaczepki? nie. \n'
# ---
# 251c243
# < (' \n', ' GRZEGORZ \n')
# > ' GRZEGORZ \n'
# ---
# 275c267
# < (' Odstąpcie, głupcy; schowajcie miecze do pochew. Sami nie wiecie, co robicie. \n', ' Odstąpcie, głupcy; schowajcie do pochew. Sami nie wiecie, co robicie. \n')
# > ' Odstąpcie, głupcy; schowajcie do pochew. Sami nie wiecie, co robicie. \n'
# ---
# 277c269
# < (' / swoim mieczem. / \n', ' / Rozdziela ich swoim mieczem. / \n')
# > ' / Rozdziela ich swoim mieczem. / \n'
# ---
# 301c293
# < (' / Walczą. Nadchodzi kilku przyjaciół obu partii mieszają się do zwady; wkrótce potem wchodzą mieszczanie z pałkami. / \n', ' / Nadchodzi kilku przyjaciół obu partii i mieszają się do zwady; wkrótce potem wchodzą mieszczanie z pałkami. / \n')
# > ' / Nadchodzi kilku przyjaciół obu partii i mieszają się do zwady; wkrótce potem wchodzą mieszczanie z pałkami. / \n'
# ---
# 307c299
# < (' Precz z Montekimi, precz z Kapuletami! \n', ' Precz Montekimi, precz z Kapuletami! \n')
# > ' Precz Montekimi, precz z Kapuletami! \n'
# ---
# 325c317
# < (' Miecz, mówię! Stary Monteki \n', ' Miecz, mówię! Stary Monteki nadchodzi. \n')
# > ' Miecz, mówię! Stary Monteki nadchodzi. \n'
# ---
# 335c327
# < (' / do żony / \n', ' / do / \n')
# > ' / do / \n'
# ---
# 337c329
# < ('                         mnie, pani. \n', '                         Puść mnie, pani. \n')
# > '                         Puść mnie, pani. \n'
# ---
# 340c332
# < (' PANI MONTEKI Nie puszczę cię na krok, gdy wróg przed tobą. \n', ' PANI MONTEKI \n')
# > ' PANI MONTEKI \n'
# ---
# 342a334
# < ' Nie puszczę cię na krok, gdy wróg przed tobą. \n'
# ---
# 342a335
# < '\n'
# ---
# 351c345
# < (' własnych żył swoich źródle purpurowym; \n', ' W własnych żył swoich źródle purpurowym; \n')
# > ' W własnych żył swoich źródle purpurowym; \n'
# ---
# 352c346
# < (' Pod karą tortur wypuśćcie natychmiast \n', ' Pod karą tortur wypuśćcie natychmiast Z dłoni skrwawionych tę broń buntowniczą \n')
# > ' Pod karą tortur wypuśćcie natychmiast Z dłoni skrwawionych tę broń buntowniczą \n'
# ---
# 353c347
# < (' Z dłoni skrwawionych tę broń buntowniczą \n', ' I posłuchajcie tego, co niniejszym \n')
# > ' I posłuchajcie tego, co niniejszym \n'
# ---
# 354c348
# < (' I posłuchajcie tego, co niniejszym Wasz rozjątrzony książę postanawia. \n', ' Wasz książę postanawia. \n')
# > ' Wasz książę postanawia. \n'
# ---
# 358d352
# < ' Tak że poważni wiekiem i zasługą \n'
# ---
# 359c352
# < (' Obywatele werońscy musieli \n', ' Tak że poważni wiekiem zasługą \n')
# > ' Tak że poważni wiekiem zasługą \n'
# ---
# 360c353
# < (' Porzucić swoje wygodne przybory \n', ' Obywatele werońscy musieli Porzucić swoje wygodne przybory \n')
# > ' Obywatele werońscy musieli Porzucić swoje wygodne przybory \n'
# ---
# 366c359
# < (' A teraz wszyscy ustąpcie niezwłocznie. \n', ' A teraz wszyscy niezwłocznie. \n')
# > ' A teraz wszyscy niezwłocznie. \n'
# ---
# 370c363
# < (' Dalsza ma wola oznajmiona będzie. \n', ' Dalsza ma wola oznajmiona \n')
# > ' Dalsza ma wola oznajmiona \n'
# ---
# 371c364
# < (' Jeszcze raz wzywam wszystkich tu obecnych Pod karą śmierci, aby się rozeszli. / Książę z orszakiem wychodzi. Kapulet, Pani Kapulet, Tybalt, obywatele i słudzy. / \n', ' Jeszcze raz wzywam wszystkich tu obecnych Pod karą aby się rozeszli. \n')
# > ' Jeszcze raz wzywam wszystkich tu obecnych Pod karą aby się rozeszli. \n'
# ---
# 373a366
# < ' / Książę z orszakiem wychodzi. Podobnież Kapulet, Pani Kapulet, Tybalt, obywatele i słudzy. / \n'
# ---
# 374a368
# < '\n'
# ---
# 383c378
# < (' I wasi już się bili, kiedym nadszedł; \n', ' I wasi już się bili, kiedym \n')
# > ' I wasi już się bili, kiedym \n'
# ---
# 385c380
# < (' Wtem wpadł szalony Tybalt z gołym mieczem, \n', ' Wtem szalony Tybalt z gołym mieczem, \n')
# > ' Wtem szalony Tybalt z gołym mieczem, \n'
# ---
# 387d382
# < ' Jął się wywijać nim i siec powietrze, \n'
# ---
# 388c382
# < (' Które świszczało tylko szydząc z marnych \n', ' Jął się wywijać nim i siec powietrze, Które świszczało tylko szydząc z marnych \n')
# > ' Jął się wywijać nim i siec powietrze, Które świszczało tylko szydząc z marnych \n'
# ---
# 392c386
# < (' Aż książę nadszedł i rozdzielił wszystkich. \n', ' Aż książę nadszedł i wszystkich. \n')
# > ' Aż książę nadszedł i wszystkich. \n'
# ---
# 395c389
# < (' PANI MONTEKI \n', ' MONTEKI \n')
# > ' MONTEKI \n'
# ---
# 397c391
# < (' Lecz gdzież Romeo? Widział żeś go dzisiaj? \n', ' Lecz Romeo? Widział żeś go dzisiaj? \n')
# > ' Lecz Romeo? Widział żeś go dzisiaj? \n'
# ---
# 404d398
# < ' W złotych się oknach wschodu ukazało, \n'
# ---
# 405c398
# < (' Troski wygnały mię z dala od domu \n', ' W złotych się oknach wschodu ukazało, Troski wygnały mię z dala od domu \n')
# > ' W złotych się oknach wschodu ukazało, Troski wygnały mię z dala od domu \n'
# ---
# 408c401
# < (' Tam, już tak rano, syn wasz się przechadzał. \n', ' Tam, już tak rano, syn się przechadzał. \n')
# > ' Tam, już tak rano, syn się przechadzał. \n'
# ---
# 411c404
# < (' I w najciemniejszej się gęstwinie. \n', ' I w najciemniejszej ukrył się gęstwinie. \n')
# > ' I w najciemniejszej ukrył się gęstwinie. \n'
# ---
# 427c420
# < (' Zaczęło ściągać cienistą kotarę, \n', ' Zaczęło ściągać kotarę, \n')
# > ' Zaczęło ściągać kotarę, \n'
# ---
# 430c423
# < (' Zasłaniał okna przed jasnym dnia blaskiem \n', ' Zasłaniał okna przed jasnym dnia \n')
# > ' Zasłaniał okna przed jasnym dnia \n'
# ---
# 438c431
# < (' Szanowny stryju, znasz–że powód tego? \n', ' Szanowny znasz–że powód tego? \n')
# > ' Szanowny znasz–że powód tego? \n'
# ---
# 453c446
# < (' i sam, i przez drugich, \n', ' Wybadywałem i sam, i przez drugich, \n')
# > ' Wybadywałem i sam, i przez drugich, \n'
# ---
# 455d448
# < ' Tak im jest wierny, tak zamknięty w sobie, \n'
# ---
# 456c448
# < (' Od otwartości wszelkiej tak daleki \n', ' Tak im jest wierny, tak w sobie, Od otwartości wszelkiej tak daleki \n')
# > ' Tak im jest wierny, tak w sobie, Od otwartości wszelkiej tak daleki \n'
# ---
# 457c449
# < (' Jak pączek kwiatu, co robak gryzie, \n', ' Jak pączek kwiatu, co go robak gryzie, \n')
# > ' Jak pączek kwiatu, co go robak gryzie, \n'
# ---
# 458c450
# < (' Nim światu wonny swój kielich roztoczył \n', ' Nim światu wonny swój roztoczył \n')
# > ' Nim światu wonny swój roztoczył \n'
# ---
# 460d452
# < ' Gdybyśmy dojść tych trosk zarodka, \n'
# ---
# 461c452
# < (' Nie zbrakłoby nam zaradczego środka. \n', ' Gdybyśmy mogli dojść tych trosk zarodka, Nie zbrakłoby nam zaradczego środka. \n')
# > ' Gdybyśmy mogli dojść tych trosk zarodka, Nie zbrakłoby nam zaradczego środka. \n'
# ---
# 463c454
# < (' / ukazuje się w głębi. / \n', ' / Romeo ukazuje się w głębi. / \n')
# > ' / Romeo ukazuje się w głębi. / \n'
# ---
# 468c459
# < (' Oto nadchodzi. Odstąpcie na stronę; \n', ' Oto Odstąpcie na stronę; \n')
# > ' Oto Odstąpcie na stronę; \n'
# ---
# 504c495
# < (' Tak jest. Lecz cóż tak chwile twoje \n', ' Tak jest. Lecz cóż tak chwile twoje dłuży? \n')
# > ' Tak jest. Lecz cóż tak chwile twoje dłuży? \n'
# ---
# 512c503
# < (' \n', ' BENWOLIO \n')
# > ' BENWOLIO \n'
# ---
# 529c520
# < (' Brak jej skąd bym pragnął wzajemności. \n', ' Brak jej tam, skąd bym pragnął wzajemności. \n')
# > ' Brak jej tam, skąd bym pragnął wzajemności. \n'
# ---
# 534a525
# < ' Niestety! Czemuż, zdając się niebianką, \n'
# ---
# 534c526
# < (' Niestety! Czemuż, zdając się niebianką, Miłość jest gruncie tak tyranką? ROMEO \n', ' Miłość w gruncie tak srogą tyranką? \n')
# > ' Miłość w gruncie tak srogą tyranką? \n'
# ---
# 536a528
# < '\n'
# ---
# 536a529
# < ' ROMEO \n'
# ---
# 536a530
# < '\n'
# ---
# 536c531
# < (' Niestety! Czemuż, z zasłoną na skroni, \n', ' Niestety! z zasłoną na skroni, \n')
# > ' Niestety! z zasłoną na skroni, \n'
# ---
# 538c533
# < (' Gdzież dziś jeść Ach! Był tu podobno \n', ' Gdzież dziś jeść będziem? Ach! Był tu \n')
# > ' Gdzież dziś jeść będziem? Ach! Był tu \n'
# ---
# 539c534
# < (' Jakiś spór? Nie mów mi o nim, wiem wszystko. \n', ' spór? Nie mów mi o nim, wiem wszystko. \n')
# > ' spór? Nie mów mi o nim, wiem wszystko. \n'
# ---
# 540c535
# < (' W grze tu wielka, lecz i miłość. \n', ' W grze tu nienawiść wielka, lecz i miłość. \n')
# > ' W grze tu nienawiść wielka, lecz i miłość. \n'
# ---
# 545c540
# < (' Szpetny chaosie wdzięków! Ciężki puchu! \n', ' Szpetny wdzięków! Ciężki puchu! \n')
# > ' Szpetny wdzięków! Ciężki puchu! \n'
# ---
# 546c541
# < (' Jasna mgło! Zimny żarze! Martwy ruchu! \n', ' mgło! Zimny żarze! Martwy ruchu! \n')
# > ' mgło! Zimny żarze! Martwy ruchu! \n'
# ---
# 547c542
# < (' Śnie bez snu! Taką to w sobie zawiłość, \n', ' Śnie bez snu! Taką to w zawiłość, \n')
# > ' Śnie bez snu! Taką to w zawiłość, \n'
# ---
# 548c543
# < (' niełączność łączy moja miłość. \n', ' Taką niełączność łączy moja miłość. \n')
# > ' Taką niełączność łączy moja miłość. \n'
# ---
# 549c544
# < (' Czy się śmiejesz? \n', ' Czy się nie śmiejesz? \n')
# > ' Czy się nie śmiejesz? \n'
# ---
# 552c547
# < (' BENWOLIO \n', ' Nie, płakałbym raczej. \n')
# > ' Nie, płakałbym raczej. \n'
# ---
# 554d549
# < '                         Nie, płakałbym \n'
# ---
# 556d550
# < '\n'
# ---
# 572c565
# < (' Dość już ciężył mój smutek, ty jego \n', ' Dość mi już ciężył mój smutek, ty jego \n')
# > ' Dość mi już ciężył mój smutek, ty jego \n'
# ---
# 577d570
# < ' To dym, z parą westchnień się unosi; \n'
# ---
# 578d570
# < ' To żar, co w oku szczęśliwego płonie; \n'
# ---
# 579c570
# < (' Morze łez, w którym nieszczęśliwy tonie. \n', ' To dym, co z parą westchnień się unosi; To żar, co w oku szczęśliwego płonie; \n')
# > ' To dym, co z parą westchnień się unosi; To żar, co w oku szczęśliwego płonie; \n'
# ---
# 580c571
# < (' Czymże jest więcej? Istnym amalgamem, \n', ' Morze łez, w którym nieszczęśliwy tonie. Czymże jest więcej? Istnym amalgamem, \n')
# > ' Morze łez, w którym nieszczęśliwy tonie. Czymże jest więcej? Istnym amalgamem, \n'
# ---
# 582c573
# < (' Bądź zdrów. \n', ' zdrów. \n')
# > ' zdrów. \n'
# ---
# 590c581
# < (' Gdybyś mą przyjaźń z kwitkiem tak zostawił. \n', ' Gdybyś mą przyjaźń z kwitkiem zostawił. \n')
# > ' Gdybyś mą przyjaźń z kwitkiem zostawił. \n'
# ---
# 596c587
# < (' To nie Romeo, co rozmawia z tobą. \n', ' To nie co rozmawia z tobą. \n')
# > ' To nie co rozmawia z tobą. \n'
# ---
# 621c612
# < (' Dobre dla tego, kto jest w tak złym stanie? \n', ' dla tego, kto jest w tak stanie? \n')
# > ' dla tego, kto jest w tak stanie? \n'
# ---
# 622c613
# < (' A kobietę kocham. \n', ' A więc, kobietę kocham. \n')
# > ' A więc, kobietę kocham. \n'
# ---
# 633c624
# < (' Biegle I ta, którą kocham, \n', ' Biegle celujesz. I ta, którą kocham, \n')
# > ' Biegle celujesz. I ta, którą kocham, \n'
# ---
# 644c635
# < (' A właśnieś chybił. Niczym tu kołczany \n', ' A właśnieś chybił. Niczym tu \n')
# > ' A właśnieś chybił. Niczym tu \n'
# ---
# 646c637
# < (' Pod twardą zbroją wstydliwości swojej \n', ' Pod wstydliwości swojej \n')
# > ' Pod wstydliwości swojej \n'
# ---
# 648c639
# < (' Szydzi z nawału zaklęć oblężniczych; \n', ' Szydzi z nawału zaklęć \n')
# > ' Szydzi z nawału zaklęć \n'
# ---
# 652c643
# < (' Że kiedy umrze, do grobu nią zstąpi \n', ' kiedy umrze, do grobu z nią zstąpi \n')
# > ' kiedy umrze, do grobu z nią zstąpi \n'
# ---
# 653c644
# < (' bogactwo, którego tak skąpi. \n', ' Całe bogactwo, którego tak skąpi. \n')
# > ' Całe bogactwo, którego tak skąpi. \n'
# ---
# 663c654
# < (' Tak jest; i skąpstwo to jest \n', ' Tak jest; i to jest marnotrawstwem, \n')
# > ' Tak jest; i to jest marnotrawstwem, \n'
# ---
# 668c659
# < (' Przysięgła nie kochać i dzięki \n', ' Przysięgła nigdy nie kochać i dzięki \n')
# > ' Przysięgła nigdy nie kochać i dzięki \n'
# ---
# 674c665
# < (' Jest na to rada: przestań myśleć o niej. \n', ' Jest na rada: przestań myśleć o niej. \n')
# > ' Jest na rada: przestań myśleć o niej. \n'
# ---
# 686c677
# < (' Rozpatrywania się pięknościach. \n', ' Rozpatrywania się w innych pięknościach. \n')
# > ' Rozpatrywania się w innych pięknościach. \n'
